# %% [markdown]
# # Docking workflow
# This is a quick guide to setting up a simple linear workflow for docking small molecules.
#
# ## Imports
# We will first import generally useful stuff - *maize* uses `pathlib` whenever file system paths are involved:

# %%
from pathlib import Path

# %% [markdown]
# The core functionality of *maize* is contained in the `Workflow` class.

# %%
from maize.core.workflow import Workflow

# %% [markdown]
# We will also need some steps that allow us to load and save any kind of data:

# %%
from maize.steps.io import LoadData, LogResult, Return

# %% [markdown]
# Domain-specific steps are contained in the *maize-contrib* namespace package. We will need a docking step (`AutoDockGPU`) and a step to generate small molecule isomers / conformers (`Gypsum`).

# %%
from maize.steps.mai.docking.adv import AutoDockGPU
from maize.steps.mai.molecule import Gypsum
from maize.utilities.chem import IsomerCollection

# %% [markdown]
# ## Preparation
# ### Configuration
# Most available workflow nodes in Maize require some system-specific configuration, such as the location of external software packages, names of modules, or python packages. This configuration takes place in a TOML file, by default Maize looks in `$XDG_CONFIG_HOME/maize.toml` (`~/.config/maize.toml`) for a file like this:

# %%
# !cat docking-example-config.toml
# Out:
# [autodockgpu]
# python = "/home/${USER}/miniconda3/envs/maize-meeko/bin/python"
# modules = ["CUDA", "GCC"]
# commands.autodock_gpu = "/projects/mai/users/${USER}_thomas/src/AutoDock-GPU/bin/autodock_gpu_64wi"
#
# [gypsum]
# scripts.gypsum.interpreter = "/home/${USER}/miniconda3/envs/gypsum/bin/python"
# scripts.gypsum.location = "/projects/mai/users/${USER}_thomas/src/gypsum_dl/run_gypsum_dl.py"

# %% [markdown]
# Here, we have configured the `AutoDockGPU` node by specifying the python interpreter to be used for its execution, the modules that need to be loaded before, as well as the precise location of the `autodock_gpu` command. We also need this information for `Gypsum` (to embed molecules), but since it's a script, we provide the script location and interpreter to use separately.
#
# How to provide this documentation is described in the documentation for each node. They will often have a `required_callables` class attribute specifying the name of the callable to be provided in the configuration. In the above example, `AutoDockGPU` requires a callable named `autodock_gpu`, the path to which we can provide using `commands.autodock_gpu`. In other cases the executable might already be in your `$PATH` (or loaded through the module system), in which case no additional configuration is required.

# %% [markdown]
# ### Grid
# We also need to specify the target grid file. `AutoDockGPU` requires an `.fld` file with references to a few other files to operate correctly.

# %%
grid = Path("../maize/steps/mai/docking/data/1stp/1stp_protein.maps.fld")

# %% [markdown]
# ## Workflow definition
# We can now create our workflow instance, give it a name, and possibly specify a logging level. `cleanup_temp=False` allows us to keep all files related to the execution instead of just using temporary directories. We also load our custom configuration because it's in a non-standard location.

# %%
flow = Workflow(name="dock", level="info", cleanup_temp=False)
flow.config.update(Path("docking-example-config.toml"))

# %% [markdown]
# ### Adding nodes
# Workflow nodes can be added using the `add` method. We will need a node to load data and inject it into the workflow (`LoadData`), the molecule preparation and docking steps (`Gypsum` and `AutoDockGPU`), and steps to handle the output (`LogResult` and `Return`).
#
# Note that steps that accept any kind of generic data should be parameterised with the type. This is the case for `LoadData`, in this case we will be passing it a list of SMILES codes (`list[str]`), and also for `Return`. Doing this allows for all connections to be type-checked statically, catching many workflow construction errors.

# %%
load = flow.add(LoadData[list[str]])
embe = flow.add(Gypsum)
dock = flow.add(AutoDockGPU)
save = flow.add(LogResult)
retu = flow.add(Return[list[IsomerCollection]])

# %% [markdown]
# ## Configuration
# We can now set the required parameters. `LoadData` requires setting the `data` parameter with the data we want to send on to the next node. We also specify that we want a maximum of 2 variants for the isomer generation / embedding step, and we also need to specify the docking grid:

# %%
load.data.set(["Nc1ccc(ccc1N)C", "Nc1ccc(cc1N)C"])
embe.n_variants.set(2)
dock.grid_file.set(grid)

# %% [markdown]
# ### Connections
# All that is left to do now is to connect all nodes together:

# %%
flow.connect(load.out, embe.inp)
flow.connect(embe.out, dock.inp)
flow.connect(dock.out, retu.inp)
flow.connect(dock.out_scores, save.inp)

# %% [markdown]
# We can check if everything is ready to run using the `check()` method. It will ensure all nodes in the graph are connected properly (with correct types) and also go through each node's software requirements, making sure it's all available:

# %%
flow.check()

# %% [markdown]
# If you installed *maize* with `graphviz` you can visualize the workflow in your notebook:

# %%
flow.visualize()

# %% [markdown]
# ## Running
# We can now run our graph!

# %%
flow.execute()
# Out:
# 2023-08-11 17:25:31,912 |     INFO |             dock |
#               ___           ___                       ___           ___
#              /\__\         /\  \          ___        /\  \         /\  \
#             /::|  |       /::\  \        /\  \       \:\  \       /::\  \
#            /:|:|  |      /:/\:\  \       \:\  \       \:\  \     /:/\:\  \
#           /:/|:|__|__   /::\~\:\  \      /::\__\       \:\  \   /::\~\:\  \
#          /:/ |::::\__\ /:/\:\ \:\__\  __/:/\/__/ _______\:\__\ /:/\:\ \:\__\
#          \/__/~~/:/  / \/__\:\/:/  / /\/:/  /    \::::::::/__/ \:\~\:\ \/__/
#                /:/  /       \::/  /  \::/__/      \:\~~\~~      \:\ \:\__\
#               /:/  /        /:/  /    \:\__\       \:\  \        \:\ \/__/
#              /:/  /        /:/  /      \/__/        \:\__\        \:\__\
#              \/__/         \/__/                     \/__/         \/__/
#
#
# 2023-08-11 17:25:31,999 |     INFO |           gypsum | Starting up
# 2023-08-11 17:25:32,190 |     INFO |           return | Starting up
# 2023-08-11 17:25:32,254 |     INFO |         loaddata | Starting up
# 2023-08-11 17:25:32,362 |     INFO |             dock | Node 'loaddata' finished (1/5)
# 2023-08-11 17:25:32,359 |     INFO |         loaddata | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:32,359 |     INFO |         loaddata | Shutting down, runtime: 0:00:00.000918s
# 2023-08-11 17:25:32,361 |     INFO |         loaddata | Shutting down, total time: 0:00:00.105987s
# 2023-08-11 17:25:32,668 |     INFO |      autodockgpu | Starting up
# 2023-08-11 17:25:32,852 |     INFO |        logresult | Starting up
# 2023-08-11 17:25:33,516 |     INFO |             dock | Node 'gypsum' finished (2/5)
# 2023-08-11 17:25:33,513 |     INFO |           gypsum | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:33,514 |     INFO |           gypsum | Shutting down, runtime: 0:00:01.152313s
# 2023-08-11 17:25:33,515 |     INFO |           gypsum | Shutting down, total time: 0:00:01.514683s
# 2023-08-11 17:25:34,457 |     INFO |      autodockgpu | Parsed isomer 'UPIWLIWRZMYFKW-ITHFDTRPNA-P', score -3.47
# 2023-08-11 17:25:34,494 |     INFO |      autodockgpu | Parsed isomer 'UPIWLIWRZMYFKW-NNELSRSVNA-P', score -2.49
# 2023-08-11 17:25:34,517 |     INFO |      autodockgpu | Parsed isomer 'DGRGLKZMKWPMOH-UHFFFAOYNA-N', score -4.41
# 2023-08-11 17:25:34,555 |     INFO |             dock | Node 'return' finished (3/5)
# 2023-08-11 17:25:34,554 |     INFO |           return | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:34,554 |     INFO |           return | Shutting down, runtime: 0:00:00.004477s
# 2023-08-11 17:25:34,555 |     INFO |           return | Shutting down, total time: 0:00:02.364368s
# 2023-08-11 17:25:34,679 |     INFO |             dock | Node 'logresult' finished (4/5)
# 2023-08-11 17:25:34,674 |     INFO |        logresult | Received data: '[-3.47 -4.41]'
# 2023-08-11 17:25:34,677 |     INFO |        logresult | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:34,677 |     INFO |        logresult | Shutting down, runtime: 0:00:00.004038s
# 2023-08-11 17:25:34,678 |     INFO |        logresult | Shutting down, total time: 0:00:01.825436s
# 2023-08-11 17:25:34,776 |     INFO |             dock | Node 'autodockgpu' finished (5/5)
# 2023-08-11 17:25:34,773 |     INFO |      autodockgpu | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:34,777 |     INFO |             dock | All nodes finished, stopping...
# 2023-08-11 17:25:34,774 |     INFO |      autodockgpu | Shutting down, runtime: 0:00:01.153673s
# 2023-08-11 17:25:34,775 |     INFO |      autodockgpu | Shutting down, total time: 0:00:02.105479s
# 2023-08-11 17:25:35,279 |     INFO |             dock | Total runtime: 0:00:02.803533s
# 2023-08-11 17:25:35,283 |     INFO |             dock | Execution completed :)
# 	5 nodes completed successfully
# 	0 nodes stopped due to closing ports
# 	0 nodes failed
# 	0:00:07.915953s total walltime
# 	0:00:05.600534s spent waiting for resources or other nodes

# %% [markdown]
# ## Results
# If all went well you should see a summary of the workflow run in the log above. `LogResult` recorded the docking scores and printed them to the log, but we also have access to the docked conformations through the `Return` node. To access this data, just call `get()`:

# %%
mols = retu.get()
mols
# Out:
# [IsomerCollection('CC1CC[C@@H]([NH3+])[C@@H]([NH3+])CC1', n_isomers=2, best_score=-3.47),
#  IsomerCollection('Cc1ccc(N)c(N)c1', n_isomers=1, best_score=-4.41)]

# %% [markdown]
# Here, `IsomerCollection` is a simple container around `Isomer` objects, which in turn are pythonic wrappers around RDKit molecules. These can be accessed using the `_molecule` attribute:

# %%
mols[0].molecules[0]._molecule

# %% [markdown]
# # High-throughput docking
# The workflow above is a classic example of a directed acyclic graph (DAG). Each step is effectively run sequentially, which is not a problem for a small number of molecules, but can become a problem for very large amounts, as we might spend a lot of time embedding molecules, while we could already start docking some of them.
#
# In Maize we can sidestep this problem by batching our data and sending it through the same workflow repeatedly. To do this we will need two generic helper nodes, `Batch` and `Combine`:

# %%
import numpy as np
from numpy.typing import NDArray

from maize.steps.plumbing import Batch, Combine
from maize.steps.io import Void

# %% [markdown]
# ## Workflow
# We can now again build our workflow, we will start just like before:

# %%
flow = Workflow(name="dock-ht", level="info", cleanup_temp=False)
flow.config.update(Path("docking-example-config.toml"))

# %% [markdown]
# We again add all required nodes just like before, as well as the `Batch` and `Combine` nodes. The former will receive a list of items and split it into smaller lists, while the latter will perform the opposite. This will allow us to send smaller batches of SMILES to be docked, allowing molecules to be embedded on the CPU while the previous batch is already docking on the GPU. To make this possible, both `Gypsum` and `AutoDockGPU` will need to be able to continuously accept data, we can set this option with `loop=True`. We will finally simplify things a bit and just send the docked molecule conformations to a `Void` node, discarding them (equivalent to `/dev/null`) and only keeping the scores.

# %%
load = flow.add(LoadData[list[str]])
batch = flow.add(Batch[str])
embe = flow.add(Gypsum, loop=True)
dock = flow.add(AutoDockGPU, loop=True)
comb = flow.add(Combine[NDArray[np.float32]])
save = flow.add(LogResult)
void = flow.add(Void)

# %% [markdown]
# ### Configuration
# We again configure our workflow as before:

# %%
load.data.set(["Nc1ccc(ccc1N)C", "Nc1ccc(cc1N)C", "Nc1cc(F)c(cc1N)C", "Nc1ccc(cc1N)C(F)"])
embe.n_variants.set(2)
dock.grid_file.set(grid)

# %% [markdown]
# However, we now also need to set the number of batches to use, and we need to set the same value for both `Batch` and `Combine`. Instead of setting both individually we can combine both parameters into a single one to make the setting less error-prone using `combine_parameters`:

# %%
n_batches = flow.combine_parameters(batch.n_batches, comb.n_batches)
n_batches.set(2)

# %% [markdown]
# We again connect everything, but this time take a shortcut by using `connect_all`:

# %%
flow.connect_all(
    (load.out, batch.inp),
    (batch.out, embe.inp),
    (embe.out, dock.inp),
    (dock.out, void.inp),
    (dock.out_scores, comb.inp),
    (comb.out, save.inp),
)

# %% [markdown]
# We check everything's okay and look at the graph structure:

# %%
flow.check()
flow.visualize()

# %% [markdown]
# ### Run
# Let's run it!

# %%
flow.execute()
# Out:
# 2023-08-11 17:25:36,867 |     INFO |          dock-ht |
#               ___           ___                       ___           ___
#              /\__\         /\  \          ___        /\  \         /\  \
#             /::|  |       /::\  \        /\  \       \:\  \       /::\  \
#            /:|:|  |      /:/\:\  \       \:\  \       \:\  \     /:/\:\  \
#           /:/|:|__|__   /::\~\:\  \      /::\__\       \:\  \   /::\~\:\  \
#          /:/ |::::\__\ /:/\:\ \:\__\  __/:/\/__/ _______\:\__\ /:/\:\ \:\__\
#          \/__/~~/:/  / \/__\:\/:/  / /\/:/  /    \::::::::/__/ \:\~\:\ \/__/
#                /:/  /       \::/  /  \::/__/      \:\~~\~~      \:\ \:\__\
#               /:/  /        /:/  /    \:\__\       \:\  \        \:\ \/__/
#              /:/  /        /:/  /      \/__/        \:\__\        \:\__\
#              \/__/         \/__/                     \/__/         \/__/
#
#
# 2023-08-11 17:25:37,074 |     INFO |            batch | Starting up
# 2023-08-11 17:25:37,258 |     INFO |           gypsum | Starting up
# 2023-08-11 17:25:37,381 |     INFO |        logresult | Starting up
# 2023-08-11 17:25:37,535 |     INFO |             void | Starting up
# 2023-08-11 17:25:37,543 |     INFO |         loaddata | Starting up
# 2023-08-11 17:25:37,549 |     INFO |            batch | Sending batch 0/2
# 2023-08-11 17:25:37,610 |     INFO |          combine | Starting up
# 2023-08-11 17:25:37,649 |     INFO |         loaddata | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:37,652 |     INFO |          dock-ht | Node 'loaddata' finished (1/7)
# 2023-08-11 17:25:37,649 |     INFO |         loaddata | Shutting down, runtime: 0:00:00.000942s
# 2023-08-11 17:25:37,649 |     INFO |         loaddata | Shutting down, total time: 0:00:00.106057s
# 2023-08-11 17:25:37,651 |     INFO |            batch | Sending batch 1/2
# 2023-08-11 17:25:37,754 |     INFO |          dock-ht | Node 'batch' finished (2/7)
# 2023-08-11 17:25:37,752 |     INFO |            batch | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:37,752 |     INFO |            batch | Shutting down, runtime: 0:00:00.002247s
# 2023-08-11 17:25:37,753 |     INFO |            batch | Shutting down, total time: 0:00:00.678544s
# 2023-08-11 17:25:38,187 |     INFO |      autodockgpu | Starting up
# 2023-08-11 17:25:39,444 |  WARNING |      autodockgpu | Docking isomer 'UPIWLIWRZMYFKW-YUMQZZPRNA-N' failed
# 2023-08-11 17:25:39,446 |  WARNING |      autodockgpu | Docking isomer 'UPIWLIWRZMYFKW-WHUPJOBBNA-N' failed
# 2023-08-11 17:25:39,452 |     INFO |      autodockgpu | Parsed isomer 'DGRGLKZMKWPMOH-UHFFFAOYNA-N', score -4.43
# 2023-08-11 17:25:39,605 |     INFO |          combine | Received batch 1/2
# 2023-08-11 17:25:40,613 |     INFO |          dock-ht | Node 'gypsum' finished (3/7)
# 2023-08-11 17:25:40,612 |     INFO |           gypsum | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:40,612 |     INFO |           gypsum | Shutting down, runtime: 0:00:03.145184s
# 2023-08-11 17:25:40,612 |     INFO |           gypsum | Shutting down, total time: 0:00:03.354498s
# 2023-08-11 17:25:40,717 |  WARNING |      autodockgpu | Docking isomer 'SNHYTHIEXHWXCQ-UHFFFAOYNA-N' failed
# 2023-08-11 17:25:40,720 |  WARNING |      autodockgpu | Docking isomer 'BLUAPHUUFWSBEL-UHFFFAOYNA-N' failed
# 2023-08-11 17:25:40,830 |     INFO |          combine | Received batch 2/2
# 2023-08-11 17:25:40,836 |     INFO |          dock-ht | Node 'logresult' finished (4/7)
# 2023-08-11 17:25:40,834 |     INFO |        logresult | Received data: '[nan, -4.43, nan, nan]'
# 2023-08-11 17:25:40,835 |     INFO |        logresult | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:40,835 |     INFO |        logresult | Shutting down, runtime: 0:00:00.002284s
# 2023-08-11 17:25:40,836 |     INFO |        logresult | Shutting down, total time: 0:00:03.454304s
# 2023-08-11 17:25:40,932 |     INFO |          dock-ht | Node 'autodockgpu' finished (5/7)
# 2023-08-11 17:25:40,931 |     INFO |      autodockgpu | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:40,931 |     INFO |      autodockgpu | Shutting down, runtime: 0:00:01.762604s
# 2023-08-11 17:25:40,932 |     INFO |      autodockgpu | Shutting down, total time: 0:00:02.744990s
# 2023-08-11 17:25:40,936 |     INFO |          dock-ht | Node 'combine' finished (6/7)
# 2023-08-11 17:25:40,933 |     INFO |          combine | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:40,933 |     INFO |          combine | Shutting down, runtime: 0:00:00.001634s
# 2023-08-11 17:25:40,934 |     INFO |          combine | Shutting down, total time: 0:00:03.323648s
# 2023-08-11 17:25:41,052 |     INFO |          dock-ht | Node 'void' finished (7/7)
# 2023-08-11 17:25:41,053 |     INFO |          dock-ht | All nodes finished, stopping...
# 2023-08-11 17:25:41,050 |     INFO |             void | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:41,050 |     INFO |             void | Shutting down, runtime: 0:00:03.505206s
# 2023-08-11 17:25:41,051 |     INFO |             void | Shutting down, total time: 0:00:03.515125s
# 2023-08-11 17:25:41,556 |     INFO |          dock-ht | Total runtime: 0:00:04.112908s
# 2023-08-11 17:25:41,557 |     INFO |          dock-ht | Execution completed :)
# 	4 nodes completed successfully
# 	3 nodes stopped due to closing ports
# 	0 nodes failed
# 	0:00:17.177166s total walltime
# 	0:00:08.757065s spent waiting for resources or other nodes

# %% [markdown]
# # Parallel docking
# While the above example allowed us to increase our throughput, we can go even further by explicitly parallelizing our workflow. In this case, we will want to run multiple docking runs in parallel, e.g. through a job submission system such as SLURM or just on a machine with multiple GPUs.
#
# We will use the `parallel` macro as a shortcut for this purpose, it will allow us to run a node in parallel and distribute data across it.

# %%
from maize.utilities.macros import parallel

# %% [markdown]
# ## Workflow
# We again setup our workflow as normal:

# %%
flow = Workflow(name="dock-parallel", level="info", cleanup_temp=False)
flow.config.update(Path("docking-example-config.toml"))

# %% [markdown]
# We can now add our nodes just as in the first example, but we now use the magical `parallel` function to convert our single `AutoDockGPU` node into a *subgraph* containing multiple copies of it. Data will be distributed using a `RoundRobin` node, i.e., one item will be sent to each output at a time, cycling through all available outputs. Outputs will be connected accordingly with a `Merge` node. If more than one output or input is present, multiple `RoundRobin` or `Merge` nodes will be used. Finally, we also need to set `loop=True` here to make sure the `AutoDockGPU` node can accept multiple rounds of inputs.

# %%
load = flow.add(LoadData[list[str]])
embe = flow.add(Gypsum, loop=True)
dock = flow.add(parallel(AutoDockGPU, n_branches=2, inputs=("inp",), outputs=("out", "out_scores"), loop=True))
save = flow.add(LogResult)
void = flow.add(Void)

# %% [markdown]
# ### Configuration
# Configuration is done just like before, the embedded molecules will then be distributed over both `AutoDockGPU` nodes.

# %%
load.data.set(["Nc1ccc(ccc1N)C", "Nc1ccc(cc1N)C", "Nc1cc(F)c(cc1N)C", "Nc1ccc(cc1N)C(F)"])
embe.n_variants.set(2)
dock.grid_file.set(grid)

# %% [markdown]
# We can again connect everything as normal, the internal connections for distribution and merging are taken care of by the `parallel` macro above.

# %%
flow.connect_all(
    (load.out, embe.inp),
    (embe.out, dock.inp),
    (dock.out, void.inp),
    (dock.out_scores, save.inp),
)

# %% [markdown]
# Let's check we're good to go, and also visualize what is going on inside `parallel`!

# %%
flow.check()
flow.visualize()

# %% [markdown]
# Let's go! Because my system only has a single GPU we won't actually see any speed up though (execution is blocked if required resources are not available).

# %%
flow.execute()
# Out:
# 2023-08-11 17:25:43,063 |     INFO |    dock-parallel |
#               ___           ___                       ___           ___
#              /\__\         /\  \          ___        /\  \         /\  \
#             /::|  |       /::\  \        /\  \       \:\  \       /::\  \
#            /:|:|  |      /:/\:\  \       \:\  \       \:\  \     /:/\:\  \
#           /:/|:|__|__   /::\~\:\  \      /::\__\       \:\  \   /::\~\:\  \
#          /:/ |::::\__\ /:/\:\ \:\__\  __/:/\/__/ _______\:\__\ /:/\:\ \:\__\
#          \/__/~~/:/  / \/__\:\/:/  / /\/:/  /    \::::::::/__/ \:\~\:\ \/__/
#                /:/  /       \::/  /  \::/__/      \:\~~\~~      \:\ \:\__\
#               /:/  /        /:/  /    \:\__\       \:\  \        \:\ \/__/
#              /:/  /        /:/  /      \/__/        \:\__\        \:\__\
#              \/__/         \/__/                     \/__/         \/__/
#
#
# 2023-08-11 17:25:43,179 |     INFO |  reap-out_scores | Starting up
# 2023-08-11 17:25:43,532 |     INFO |          sow-inp | Starting up
# 2023-08-11 17:25:43,647 |     INFO |             void | Starting up
# 2023-08-11 17:25:43,647 |     INFO |         loaddata | Starting up
# 2023-08-11 17:25:43,710 |     INFO |        logresult | Starting up
# 2023-08-11 17:25:43,753 |     INFO |         loaddata | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:43,755 |     INFO |    dock-parallel | Node 'loaddata' finished (1/9)
# 2023-08-11 17:25:43,753 |     INFO |         loaddata | Shutting down, runtime: 0:00:00.000962s
# 2023-08-11 17:25:43,753 |     INFO |         loaddata | Shutting down, total time: 0:00:00.105976s
# 2023-08-11 17:25:43,866 |     INFO |         reap-out | Starting up
# 2023-08-11 17:25:43,866 |     INFO |           gypsum | Starting up
# 2023-08-11 17:25:44,026 |     INFO |    AutoDockGPU-0 | Starting up
# 2023-08-11 17:25:44,342 |     INFO |    AutoDockGPU-1 | Starting up
# 2023-08-11 17:25:45,745 |     INFO |    dock-parallel | Node 'gypsum' finished (2/9)
# 2023-08-11 17:25:45,745 |     INFO |           gypsum | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:45,745 |     INFO |           gypsum | Shutting down, runtime: 0:00:01.771007s
# 2023-08-11 17:25:45,745 |     INFO |           gypsum | Shutting down, total time: 0:00:01.878420s
# 2023-08-11 17:25:45,752 |     INFO |    dock-parallel | Node 'sow-inp' finished (3/9)
# 2023-08-11 17:25:45,749 |     INFO |          sow-inp | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:45,749 |     INFO |          sow-inp | Shutting down, runtime: 0:00:00.501033s
# 2023-08-11 17:25:45,750 |     INFO |          sow-inp | Shutting down, total time: 0:00:02.217757s
# 2023-08-11 17:25:45,849 |     INFO |    dock-parallel | Node 'AutoDockGPU-1' finished (4/9)
# 2023-08-11 17:25:45,847 |     INFO |    AutoDockGPU-1 | Port 'inp' shutdown, exiting now...
# 2023-08-11 17:25:45,848 |     INFO |    AutoDockGPU-1 | Shutting down, runtime: 0:00:00.501154s
# 2023-08-11 17:25:45,848 |     INFO |    AutoDockGPU-1 | Shutting down, total time: 0:00:01.505806s
# 2023-08-11 17:25:46,485 |     INFO |    AutoDockGPU-0 | Parsed isomer 'UPIWLIWRZMYFKW-ITHFDTRPNA-P', score -3.35
# 2023-08-11 17:25:46,524 |  WARNING |    AutoDockGPU-0 | Docking isomer 'UPIWLIWRZMYFKW-HTQZYQBONA-N' failed
# 2023-08-11 17:25:46,526 |     INFO |    AutoDockGPU-0 | Parsed isomer 'DGRGLKZMKWPMOH-UHFFFAOYNA-N', score -4.41
# 2023-08-11 17:25:46,544 |  WARNING |    AutoDockGPU-0 | Docking isomer 'SNHYTHIEXHWXCQ-UHFFFAOYNA-N' failed
# 2023-08-11 17:25:46,545 |  WARNING |    AutoDockGPU-0 | Docking isomer 'BLUAPHUUFWSBEL-UHFFFAOYNA-N' failed
# 2023-08-11 17:25:46,779 |     INFO |    dock-parallel | Node 'AutoDockGPU-0' finished (5/9)
# 2023-08-11 17:25:46,778 |     INFO |    AutoDockGPU-0 | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:46,778 |     INFO |    AutoDockGPU-0 | Shutting down, runtime: 0:00:01.423269s
# 2023-08-11 17:25:46,778 |     INFO |    AutoDockGPU-0 | Shutting down, total time: 0:00:02.752291s
# 2023-08-11 17:25:47,196 |     INFO |    dock-parallel | Node 'logresult' finished (6/9)
# 2023-08-11 17:25:47,191 |     INFO |        logresult | Received data: '[  nan -4.41   nan   nan]'
# 2023-08-11 17:25:47,195 |     INFO |        logresult | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:47,195 |     INFO |        logresult | Shutting down, runtime: 0:00:00.004558s
# 2023-08-11 17:25:47,195 |     INFO |        logresult | Shutting down, total time: 0:00:03.484535s
# 2023-08-11 17:25:47,292 |     INFO |    dock-parallel | Node 'reap-out_scores' finished (7/9)
# 2023-08-11 17:25:47,290 |     INFO |  reap-out_scores | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:47,291 |     INFO |  reap-out_scores | Shutting down, runtime: 0:00:04.006135s
# 2023-08-11 17:25:47,291 |     INFO |  reap-out_scores | Shutting down, total time: 0:00:04.112015s
# 2023-08-11 17:25:47,494 |     INFO |    dock-parallel | Node 'reap-out' finished (8/9)
# 2023-08-11 17:25:47,491 |     INFO |         reap-out | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:47,492 |     INFO |         reap-out | Shutting down, runtime: 0:00:03.506187s
# 2023-08-11 17:25:47,492 |     INFO |         reap-out | Shutting down, total time: 0:00:03.625578s
# 2023-08-11 17:25:47,668 |     INFO |    dock-parallel | Node 'void' finished (9/9)
# 2023-08-11 17:25:47,666 |     INFO |             void | Attempt 1 of 1 succeeded
# 2023-08-11 17:25:47,669 |     INFO |    dock-parallel | All nodes finished, stopping...
# 2023-08-11 17:25:47,666 |     INFO |             void | Shutting down, runtime: 0:00:04.005189s
# 2023-08-11 17:25:47,667 |     INFO |             void | Shutting down, total time: 0:00:04.019433s
# 2023-08-11 17:25:48,172 |     INFO |    dock-parallel | Total runtime: 0:00:04.495827s
# 2023-08-11 17:25:48,174 |     INFO |    dock-parallel | Execution completed :)
# 	3 nodes completed successfully
# 	6 nodes stopped due to closing ports
# 	0 nodes failed
# 	0:00:23.701811s total walltime
# 	0:00:07.982317s spent waiting for resources or other nodes
